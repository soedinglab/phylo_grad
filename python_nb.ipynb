# %% [markdown]
# Currently using post-order DFS, this has a drawback that some non-terminal nodes come in front of some leaves.
# Would be better to sort the nodes according to their co-height (the length of the longest path to a leaf), we'll still get a topological ordering, but all leaves will be listed first.

# %%
import numpy as np
import pandas as pd
from bigtree import Node, dataframe_to_tree_by_relation, postorder_iter, levelorder_iter

# %%
path = "data/tree.txt"
with open(path) as f:
    seq_length = int(f.readline().strip('\n'))
    df = pd.read_csv(f, header=None)
df.rename(columns={0: 'parent_id', 1: 'distance', 2: 'seq'}, inplace=True)
df
# Out:
#       parent_id  distance                                                seq
# 0           707  0.026966  UUCGGUGGUUAUAGCGGUGGGGACACGCCCGGUCCCAUUCGAACCC...
# 1           708  0.008823  UUCGGUGGUCACAGCGGUGGGGAAACGCCCGGUCCCAUUCGAACCC...
# 2           709  0.026650  UUCGGUGGUAAUAGCGGUGGGGAAACGCCCGGUCCCAUUCGAACCC...
# 3           712  0.121237  -UCGGUGGCCAUAGCAGCAGGGAA-CGCCCGGACCCAUUCGAACCC...
# 4           713  0.017874  UUCGGUGGUUUUAGCGUCAGGGAAACGCCCGGUCCCAUUCGAACCC...
# ...         ...       ...                                                ...
# 1405       1404  0.008787                                                NaN
# 1406       1402  0.018323                                                NaN
# 1407       1406  0.026961                                                NaN
# 1408       1407  0.063071                                                NaN
# 1409       1408  0.026641                                                NaN
#
# [1410 rows x 3 columns]

# %%
df['child_id'] = df.index.map(str)

# %%
df['parent_id'] = df.parent_id.map(str)

# %%
root = dataframe_to_tree_by_relation(df, child_col='child_id', parent_col='parent_id', attribute_cols=['distance', 'seq'])

# %%
old_to_new = {}
new_to_old = {}

# %%
for n, node in enumerate(postorder_iter(root)):
    old_to_new[node.name] = n
    new_to_old[n] = node.name

# %%
old_to_new['-1'] = -1

# %%
start = root.children[0]

# %%
save_path = 'data/tree_preprocessed.txt'
with open(save_path, 'w') as file:
    for n, node in enumerate(postorder_iter(start)):
        file.write(f"{old_to_new[node.parent.name]},{[old_to_new[x.name] for x in node.children]},{getattr(node, 'distance', '')},{getattr(node, 'seq', '')}\n")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[10], line 2
#       1 save_path = 'data/tree_preprocessed.txt'
# ----> 2 with open(save_path, 'w') as file:
#       3     for n, node in enumerate(postorder_iter(start)):
#       4         file.write(f"{old_to_new[node.parent.name]},{[old_to_new[x.name] for x in node.children]},{getattr(node, 'distance', '')},{getattr(node, 'seq', '')}\n")
#
# File ~/miniconda3/envs/ML-cuda/lib/python3.11/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# PermissionError: [Errno 13] Permission denied: 'data/tree_preprocessed.txt'
